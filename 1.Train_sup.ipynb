# %%
# tf.debugging.set_log_device_placement(True)

# from tensorflow.python.client import device_lib
# device_lib.list_local_devices()
import os

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
# !python supervised.py --src_langs en fr --tgt_lang ja --exp_path debug_file --dico_train 'default' --exp_id 'wiki_supervised_enfr_ja' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/frwiki_300d.txt' --tgt_emb 'data/fasttext-vectors/jawiki_300d.txt' --export ''
# Out:
# INFO - 04/30/21 01:16:03 - 0:00:00 - ============ Initialized logger ============
# INFO - 04/30/21 01:16:03 - 0:00:00 - all_langs: ['en', 'fr', 'ja']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 10000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: default
#                                      emb_dim: 300
#                                      exp_id: wiki_supervised_enfr_ja
#                                      exp_name: debug
#                                      exp_path: debug_file/debug/wiki_supervised_enfr_ja
# ...

# %%
# !python supervised.py --src_langs en fr --tgt_lang zh --exp_path debug_file --dico_train 'default' --exp_id 'wiki_supervised_enfr_zh' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/frwiki_300d.txt' --tgt_emb 'data/fasttext-vectors/zhwiki_300d.txt' --export ''
# Out:
# INFO - 04/30/21 11:54:33 - 0:00:00 - ============ Initialized logger ============
# INFO - 04/30/21 11:54:33 - 0:00:00 - all_langs: ['en', 'fr', 'zh']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 10000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: default
#                                      emb_dim: 300
#                                      exp_id: wiki_supervised_enfr_zh
#                                      exp_name: debug
#                                      exp_path: debug_file/debug/wiki_supervised_enfr_zh
# ...

# %%
# !python supervised.py --max_vocab 100000 --src_langs en fr --tgt_lang pl --exp_path debug_file --dico_train 'default' --exp_id 'wiki_supervised_enfr_pl_100000' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/frwiki_300d.txt' --tgt_emb 'data/fasttext-vectors/plwiki_300d.txt' --export ''
# Out:
# INFO - 05/01/21 17:59:36 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/01/21 17:59:36 - 0:00:00 - all_langs: ['en', 'fr', 'pl']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 10000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: default
#                                      emb_dim: 300
#                                      exp_id: wiki_supervised_enfr_pl_100000
#                                      exp_name: debug
# ...

# %%
# !python supervised.py --src_langs en es --tgt_lang ja --exp_path debug_file --dico_train 'default' --exp_id 'wiki_supervised_enes_ja' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/eswiki_300d.txt' --tgt_emb 'data/fasttext-vectors/jawiki_300d.txt' --export ''
# Out:
# INFO - 04/30/21 02:30:33 - 0:00:00 - ============ Initialized logger ============
# INFO - 04/30/21 02:30:33 - 0:00:00 - all_langs: ['en', 'es', 'ja']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 10000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: default
#                                      emb_dim: 300
#                                      exp_id: wiki_supervised_enes_ja
#                                      exp_name: debug
#                                      exp_path: debug_file/debug/wiki_supervised_enes_ja
# ...
