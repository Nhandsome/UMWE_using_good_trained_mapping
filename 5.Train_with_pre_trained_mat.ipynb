# %%
# tf.debugging.set_log_device_placement(True)

# from tensorflow.python.client import device_lib
# device_lib.list_local_devices()
import os

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
fast_mpsr_from_all_esit_EN

# %%
###############################################
# !python mpsr_pre_train.py --use_good_map 1 --pre_mat_path 'data/trained/mat/unsup_fast_all' --good_map_path 'data/trained/unsupervised_fast/for_all' --src_langs es en --tgt_lang de --exp_path debug_file --dico_train 'default' --exp_id 'fast_mpsr_from_all_esen_DE' --src_embs 'data/fasttext-vectors/wiki.es.vec' 'data/fasttext-vectors/wiki.en.vec' --tgt_emb 'data/fasttext-vectors/wiki.de.vec' --export ''
# Out:
# INFO - 05/04/21 22:24:39 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/04/21 22:24:39 - 0:00:00 - all_langs: ['es', 'en', 'de']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 15000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: default
#                                      emb_dim: 300
#                                      exp_id: fast_mpsr_from_all_esen_DE
#                                      exp_name: debug
# ...

# %%
###############################################
# !python mpsr_pre_train.py --use_good_map 1 --pre_mat_path 'data/trained/mat/unsup_fast_50000' --good_map_path 'data/trained/unsupervised_fast/for_all' --src_langs es it --tgt_lang en --exp_path debug_file --dico_train 'default' --exp_id 'fast_mpsr_from_all_esit_EN_with_50000' --src_embs 'data/fasttext-vectors/wiki.es.vec' 'data/fasttext-vectors/wiki.it.vec' --tgt_emb 'data/fasttext-vectors/wiki.en.vec' --export ''
# Out:
# INFO - 05/05/21 11:52:13 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/05/21 11:52:13 - 0:00:00 - all_langs: ['es', 'it', 'en']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 15000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: default
#                                      emb_dim: 300
#                                      exp_id: fast_mpsr_from_all_esit_EN_with_50000
#                                      exp_name: debug
# ...

# %%
###############################################
# !python mpsr_pre_train.py --use_good_map 0 --pre_mat_path 'data/trained/mat/unsup_han_en_es_xx' --good_map_path 'data/trained/unsupervised_wiki' --src_langs en es --tgt_lang ja --exp_path debug_file --dico_train 'default' --exp_id 'fast_mpsr_0_wiki_enes_JA' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/eswiki_300d.txt' --tgt_emb 'data/fasttext-vectors/jawiki_300d.txt' --export ''
# Out:
# INFO - 05/06/21 12:49:22 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/06/21 12:49:22 - 0:00:00 - all_langs: ['en', 'es', 'ja']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 15000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: default
#                                      emb_dim: 300
#                                      exp_id: fast_mpsr_0_wiki_enes_JA
#                                      exp_name: debug
#                                      exp_path: debug_file/debug/fast_mpsr_0_wiki_enes_JA
# ...

# %%
###############################################
# !python mpsr_pre_train.py --use_good_map 0 --pre_mat_path 'data/trained/mat/unsup_han_en_es_xx' --good_map_path 'data/trained/unsupervised_wiki' --src_langs en es --tgt_lang pl --exp_path debug_file --dico_train 'default' --exp_id 'fast_mpsr_0_wiki_enes_PL' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/eswiki_300d.txt' --tgt_emb 'data/fasttext-vectors/plwiki_300d.txt' --export ''
# Out:
# INFO - 05/06/21 13:33:44 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/06/21 13:33:44 - 0:00:00 - all_langs: ['en', 'es', 'pl']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 15000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: default
#                                      emb_dim: 300
#                                      exp_id: fast_mpsr_0_wiki_enes_PL
#                                      exp_name: debug
#                                      exp_path: debug_file/debug/fast_mpsr_0_wiki_enes_PL
# ...

# %%
###############################################
# !python mpsr_pre_train.py --use_good_map 0 --pre_mat_path 'data/trained/mat/unsup_han_en_es_xx' --good_map_path 'data/trained/unsupervised_wiki' --src_langs en es --tgt_lang zh --exp_path debug_file --dico_train 'default' --exp_id 'fast_mpsr_0_wiki_enes_ZH' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/eswiki_300d.txt' --tgt_emb 'data/fasttext-vectors/zhwiki_300d.txt' --export ''
# Out:
# INFO - 05/06/21 13:53:55 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/06/21 13:53:55 - 0:00:00 - all_langs: ['en', 'es', 'zh']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 15000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: default
#                                      emb_dim: 300
#                                      exp_id: fast_mpsr_0_wiki_enes_ZH
#                                      exp_name: debug
#                                      exp_path: debug_file/debug/fast_mpsr_0_wiki_enes_ZH
# ...
