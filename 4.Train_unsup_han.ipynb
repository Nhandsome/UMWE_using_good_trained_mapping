# %%
# tf.debugging.set_log_device_placement(True)

# from tensorflow.python.client import device_lib
# device_lib.list_local_devices()
import os

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %% [markdown]
# es en to XX

# %%
# !python unsupervised_han.py --good_map_path 'data/trained/unsupervised_wiki' --src_langs en es --tgt_lang pl --exp_path debug_file --exp_id 'fast_unsupervised_enes_PL' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/eswiki_300d.txt'  --tgt_emb 'data/fasttext-vectors/plwiki_300d.txt' --export ''
# Out:
# INFO - 05/05/21 17:26:41 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/05/21 17:26:41 - 0:00:00 - adversarial: True
#                                      all_langs: ['en', 'es', 'pl']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 15000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dis_clip_weights: 0
#                                      dis_dropout: 0.0
#                                      dis_hid_dim: 2048
#                                      dis_input_dropout: 0.1
# ...

# %%
# !python unsupervised_han.py --good_map_path 'data/trained/unsupervised_wiki' --src_langs en es --tgt_lang ja --exp_path debug_file --exp_id 'fast_unsupervised_enes_JA' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/eswiki_300d.txt'  --tgt_emb 'data/fasttext-vectors/jawiki_300d.txt' --export ''
# Out:
# INFO - 05/05/21 19:20:45 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/05/21 19:20:45 - 0:00:00 - adversarial: True
#                                      all_langs: ['en', 'es', 'ja']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 15000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dis_clip_weights: 0
#                                      dis_dropout: 0.0
#                                      dis_hid_dim: 2048
#                                      dis_input_dropout: 0.1
# ...

# %%
# !python unsupervised_han.py --good_map_path 'data/trained/unsupervised_wiki' --src_langs en es --tgt_lang zh --exp_path debug_file --exp_id 'fast_unsupervised_enes_ZH' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/eswiki_300d.txt'  --tgt_emb 'data/fasttext-vectors/zhwiki_300d.txt' --export ''
# Out:
# INFO - 05/05/21 21:16:28 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/05/21 21:16:28 - 0:00:00 - adversarial: True
#                                      all_langs: ['en', 'es', 'zh']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 15000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dis_clip_weights: 0
#                                      dis_dropout: 0.0
#                                      dis_hid_dim: 2048
#                                      dis_input_dropout: 0.1
# ...

# %% [markdown]
# en ja to XX

# %%
# !python unsupervised_han.py --good_map_path 'data/trained/unsupervised_wiki' --src_langs en ja --tgt_lang pl --exp_path debug_file --exp_id 'fast_unsupervised_enja_PL' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/jawiki_300d.txt'  --tgt_emb 'data/fasttext-vectors/plwiki_300d.txt' --export ''
# Out:
# INFO - 05/05/21 23:12:33 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/05/21 23:12:33 - 0:00:00 - adversarial: True
#                                      all_langs: ['en', 'ja', 'pl']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 15000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dis_clip_weights: 0
#                                      dis_dropout: 0.0
#                                      dis_hid_dim: 2048
#                                      dis_input_dropout: 0.1
# ...

# %%
# !python unsupervised_han.py --good_map_path 'data/trained/unsupervised_wiki' --src_langs en ja --tgt_lang es --exp_path debug_file --exp_id 'fast_unsupervised_enja_ES' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/jawiki_300d.txt'  --tgt_emb 'data/fasttext-vectors/eswiki_300d.txt' --export ''
# Out:
# INFO - 05/05/21 23:13:12 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/05/21 23:13:12 - 0:00:00 - adversarial: True
#                                      all_langs: ['en', 'ja', 'es']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 15000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dis_clip_weights: 0
#                                      dis_dropout: 0.0
#                                      dis_hid_dim: 2048
#                                      dis_input_dropout: 0.1
# ...
