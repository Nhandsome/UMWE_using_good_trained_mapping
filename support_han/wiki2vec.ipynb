# %%
from gensim.models.keyedvectors import KeyedVectors
import pandas as pd
import io

# %%
temp = KeyedVectors.load_word2vec_format("data/fasttext-vectors/frwiki_300d.txt", limit=2000)

# %%
temp.wv.vocab
# Out:
# <ipython-input-9-5a7105455e76>:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   temp.wv.vocab
# {'de': <gensim.models.keyedvectors.Vocab at 0x7f53814d8d90>,
#  'est': <gensim.models.keyedvectors.Vocab at 0x7f53814d8d00>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x7f53814d8ca0>,
#  'le': <gensim.models.keyedvectors.Vocab at 0x7f53814d8f10>,
#  'en': <gensim.models.keyedvectors.Vocab at 0x7f53814d8fa0>,
#  'et': <gensim.models.keyedvectors.Vocab at 0x7f53814d8e80>,
#  'à': <gensim.models.keyedvectors.Vocab at 0x7f53814d8e20>,
#  'du': <gensim.models.keyedvectors.Vocab at 0x7f53814d8f40>,
#  'un': <gensim.models.keyedvectors.Vocab at 0x7f53814d8dc0>,
#  'des': <gensim.models.keyedvectors.Vocab at 0x7f5380feb040>,
#  'dans': <gensim.models.keyedvectors.Vocab at 0x7f5380feb0a0>,
#  'une': <gensim.models.keyedvectors.Vocab at 0x7f5380feb100>,
#  'les': <gensim.models.keyedvectors.Vocab at 0x7f5380feb160>,
# ...

# %%
emb_path="data/fasttext-vectors/eswiki_300d.txt"

# %%
with io.open(emb_path, 'r', encoding='utf-8', newline='\n', errors='ignore') as f:
    for i, line in enumerate(f):
        if i > 3:
            break
        else :
            print(line)
# Out:
# 1828809 300
#
# ...

# %%
! bzip2 -d "data/fasttext-vectors/eswiki_300d.txt.bz2"
