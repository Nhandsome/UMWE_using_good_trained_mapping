# %%
# tf.debugging.set_log_device_placement(True)

# from tensorflow.python.client import device_lib
# device_lib.list_local_devices()
import os

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# !python unsupervised.py --src_langs en es fr de --tgt_lang pl --exp_path debug_file --exp_id 'fast_unsupervised_enesfrde_PL' --src_embs 'data/fasttext-vectors/wiki.en.vec' 'data/fasttext-vectors/wiki.es.vec' 'data/fasttext-vectors/wiki.fr.vec' 'data/fasttext-vectors/wiki.de.vec' --tgt_emb 'data/fasttext-vectors/wiki.pl.vec' --export ''
# Out:
# INFO - 05/07/21 01:00:14 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/07/21 01:00:14 - 0:00:00 - adversarial: True
#                                      all_langs: ['en', 'es', 'fr', 'de', 'pl']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 15000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dis_clip_weights: 0
#                                      dis_dropout: 0.0
#                                      dis_hid_dim: 2048
#                                      dis_input_dropout: 0.1
# ...

# %%
# !python unsupervised.py --src_langs en es fr de --tgt_lang pl --exp_path debug_file --exp_id 'fast_unsupervised_enesfrde_ZH' --src_embs 'data/fasttext-vectors/wiki.en.vec' 'data/fasttext-vectors/wiki.es.vec' 'data/fasttext-vectors/wiki.fr.vec' 'data/fasttext-vectors/wiki.de.vec' --tgt_emb 'data/fasttext-vectors/wiki.zh.vec' --export ''
# Out:
# INFO - 05/07/21 04:24:05 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/07/21 04:24:05 - 0:00:00 - adversarial: True
#                                      all_langs: ['en', 'es', 'fr', 'de', 'pl']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 15000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dis_clip_weights: 0
#                                      dis_dropout: 0.0
#                                      dis_hid_dim: 2048
#                                      dis_input_dropout: 0.1
# ...
