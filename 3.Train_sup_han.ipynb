# %%
# !python supervised_han.py --good_map_path 'data/trained/supervised' --src_langs en fr --tgt_lang ja --exp_path debug_file --dico_train 'default' --exp_id 'test_sup_enfr_ja' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/frwiki_300d.txt' --tgt_emb 'data/fasttext-vectors/jawiki_300d.txt' --export ''
# Out:
# INFO - 04/30/21 16:54:41 - 0:00:00 - ============ Initialized logger ============
# INFO - 04/30/21 16:54:41 - 0:00:00 - all_langs: ['en', 'fr', 'ja']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 10000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: default
#                                      emb_dim: 300
#                                      exp_id: test_sup_enfr_ja
#                                      exp_name: debug
#                                      exp_path: debug_file/debug/test_sup_enfr_ja
# ...

# %%
# !python supervised_han.py --good_map_path 'data/trained/supervised' --src_langs en fr --tgt_lang zh --exp_path debug_file --dico_train 'default' --exp_id 'wiki_supervised_han_enfr_zh' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/frwiki_300d.txt' --tgt_emb 'data/fasttext-vectors/zhwiki_300d.txt' --export ''
# Out:
# INFO - 04/30/21 01:49:55 - 0:00:00 - ============ Initialized logger ============
# INFO - 04/30/21 01:49:55 - 0:00:00 - all_langs: ['en', 'fr', 'zh']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 10000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: default
#                                      emb_dim: 300
#                                      exp_id: wiki_supervised_han_enfr_zh
#                                      exp_name: debug
# ...

# %%
# !python supervised_han.py --good_map_path 'data/trained/supervised' --src_langs en fr --tgt_lang pl --exp_path debug_file --dico_train 'default' --exp_id 'wiki_supervised_han_enfr_pl' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/frwiki_300d.txt' --tgt_emb 'data/fasttext-vectors/plwiki_300d.txt' --export ''
# Out:
# INFO - 04/30/21 11:11:14 - 0:00:00 - ============ Initialized logger ============
# INFO - 04/30/21 11:11:14 - 0:00:00 - all_langs: ['en', 'fr', 'pl']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 10000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: default
#                                      emb_dim: 300
#                                      exp_id: wiki_supervised_han_enfr_pl
#                                      exp_name: debug
# ...

# %%
# !python supervised_han.py --good_map_path 'data/trained/supervised' --src_langs en es --tgt_lang ja --exp_path debug_file --dico_train 'default' --exp_id 'wiki_supervised_han_enes_ja' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/eswiki_300d.txt' --tgt_emb 'data/fasttext-vectors/jawiki_300d.txt' --export ''
# Out:
# INFO - 04/30/21 02:26:58 - 0:00:00 - ============ Initialized logger ============
# INFO - 04/30/21 02:26:58 - 0:00:00 - all_langs: ['en', 'es', 'ja']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 10000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: default
#                                      emb_dim: 300
#                                      exp_id: wiki_supervised_han_enes_ja
#                                      exp_name: debug
# ...

# %%
# !python supervised_han.py --good_map_path 'data/trained/unsupervised' --src_langs en fr --tgt_lang ja --exp_path debug_file --dico_train 'default' --exp_id 'wiki_supervised_han_enfr_unsup_ja' --src_embs 'data/fasttext-vectors/enwiki_300d.txt' 'data/fasttext-vectors/frwiki_300d.txt' --tgt_emb 'data/fasttext-vectors/jawiki_300d.txt' --export ''
# Out:
# INFO - 04/30/21 03:02:17 - 0:00:00 - ============ Initialized logger ============
# INFO - 04/30/21 03:02:17 - 0:00:00 - all_langs: ['en', 'fr', 'ja']
#                                      batch_size: 32
#                                      device: cuda
#                                      dico_build: S2T&T2S
#                                      dico_eval: default
#                                      dico_max_rank: 10000
#                                      dico_max_size: 0
#                                      dico_method: csls_knn_10
#                                      dico_min_size: 0
#                                      dico_threshold: 0
#                                      dico_train: default
#                                      emb_dim: 300
#                                      exp_id: wiki_supervised_han_enfr_unsup_ja
#                                      exp_name: debug
# ...
